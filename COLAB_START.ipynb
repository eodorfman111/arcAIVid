# %%
from google.colab import drive
drive.mount('/content/drive')
import os
for p in ["/content/drive/MyDrive/arcAI/videos",
          "/content/drive/MyDrive/arcAI/models",
          "/content/drive/MyDrive/arcAI/outputs"]:
    os.makedirs(p, exist_ok=True)
print("Drive folders ready.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive folders ready.

# %%
# !pip install -q -U ultralytics opencv-python matplotlib reportlab jinja2 "pandas==2.2.2"
import pandas as pd; print("pandas", pd.__version__)
# Out:
# pandas 2.2.2

# %%
# !wget -O /content/section_picker.py "https://raw.githubusercontent.com/eodorfman111/arcAIVid/main/section_picker.py"
# Out:
# --2025-10-24 15:08:29--  https://raw.githubusercontent.com/eodorfman111/arcAIVid/main/section_picker.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-10-24 15:08:29 ERROR 404: Not Found.

# %%
# !python /content/section_picker.py \
  --videos "/content/drive/MyDrive/arcAI/videos" \
  --model "/content/drive/MyDrive/arcAI/models/best.pt" \
  --out "/content/drive/MyDrive/arcAI/outputs" \
  --sample-every 2.5 --conf 0.35 --iou 0.50 --imgsz 1280
